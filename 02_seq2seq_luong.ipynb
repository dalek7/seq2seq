# %%
import random
import numpy as np
import matplotlib.pyplot as plt

import pickle as pkl
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Input, BatchNormalization, \
    multiply, concatenate, Flatten, Activation, dot, Bidirectional, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping
import pydot as pyd

# %%
print(tensorflow.__version__)
print(tensorflow.keras.__version__)
# Out:
# 2.3.0
# 2.4.0

# %% [markdown]
# ### Create Some Data

# %%
n_ = 1000
t = np.linspace(0, 50*np.pi, n_)
# pattern + trend + noise
x1 = sum([20*np.sin(i*t+np.pi) for i in range(5)]) + 0.01*(t**2) + np.random.normal(0, 6, n_)
x2 = sum([15*np.sin(2*i*t+np.pi) for i in range(5)]) + 0.5*t + np.random.normal(0, 6, n_)
plt.figure(figsize=(15, 4))
plt.plot(range(len(x1)), x1, label='x1')
plt.plot(range(len(x2)), x2, label='x2')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# ### Split sequences to 80% train set and 20% test set
# We’ve just created two sequences, x1 and x2, by combining sin waves, trend, and random noise. Next we will preprocess x1 and x2.

# %%
train_ratio = 0.8
train_len = int(train_ratio * t.shape[0])
print(train_len)
print(t.shape[0])
# Out:
# 800
# 1000

# %% [markdown]
# ### Detrending
# It is not a must to detrend time series. However stationary time series will make model training much easier. There are many ways to detrend time series, such as taking difference of sequence with its lag1. Here for the simplicity, we assume the order of trend is known and we are just going to simply fit separate trend lines to x1 and x2, and then subtract the trend from the corresponding original sequence.
#
# We will create index number of each position in the sequence, for easier detrending and trend recover.

# %%
x_index = np.array(range(len(t)))

# %% [markdown]
# Here we will use np.polyfit to complete this small task. Note that only the first 800 data points are used to fit the trend lines, this is because we want to avoid data leak.

# %%
x1_trend_param = np.polyfit(x_index[:train_len], x1[:train_len], 2)
x2_trend_param = np.polyfit(x_index[:train_len], x2[:train_len], 1)
print(x1_trend_param)
print(x2_trend_param)
# Out:
# [ 2.41690583e-04  8.34831572e-03 -2.26813903e+00]
# [ 0.08220679 -1.63404628]

# %%
x1_trend = (x_index**2)*x1_trend_param[0]+x_index*x1_trend_param[1]+x1_trend_param[2]
x2_trend = x_index*x2_trend_param[0]+x2_trend_param[1]

# %%
plt.figure(figsize=(15, 4))
plt.plot(range(len(x1)), x1, label='x1')
plt.plot(range(len(x1_trend)), x1_trend, linestyle='--', label='x1_trend')
plt.plot(range(len(x2)), x2, label='x2')
plt.plot(range(len(x2_trend)), x2_trend, linestyle='--', label='x2_trend')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %%
x1_detrend = x1 - x1_trend
x2_detrend = x2 - x2_trend
plt.figure(figsize=(15, 4))
plt.plot(range(len(x1_detrend)), x1_detrend, label='x2_detrend')
plt.plot(range(len(x2_detrend)), x2_detrend, label='x2_detrend')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# * the first column is the detrended x1
# * the second column is the detrended x2
# * the third column is the index
# * the fourth column is the label (1 for train set and 0 for test set)

# %%
x_lbl = np.column_stack([x1_detrend, x2_detrend, x_index, [1]*train_len+[0]*(len(x_index)-train_len)])
print(x_lbl.shape)
print(x_lbl)
# Out:
# (1000, 4)
# [[  4.60808478  -3.98670138   0.           1.        ]
#  [-33.97000553 -30.07935669   1.           1.        ]
#  [-51.58071483 -36.7792393    2.           1.        ]
#  ...
#  [ 54.26424737  52.23529475 997.           0.        ]
#  [ 26.67656986  37.49176702 998.           0.        ]
#  [ 12.51470179  -2.96726613 999.           0.        ]]

# %% [markdown]
# ### Normalize
# Normalisation can help model avoid favouring large features while ignoring very small features. Here we can just simply normalise x1 and x2 by dividing the corresponding maximum values in train set.

# %%
x_train_max = x_lbl[x_lbl[:, 3]==1, :2].max(axis=0)
x_train_max = x_train_max.tolist()+[1]*2  # only normalize for the first 2 columns
print(x_train_max)
# Out:
# [79.28165273016909, 58.393196761437984, 1, 1]

# %%
x_normalize = np.divide(x_lbl, x_train_max)

# %%
plt.figure(figsize=(15, 4))
plt.plot(range(train_len), x_normalize[:train_len, 0], label='x1_train_normalized')
plt.plot(range(train_len), x_normalize[:train_len, 1], label='x2_train_normalized')
plt.plot(range(train_len, len(x_normalize)), x_normalize[train_len:, 0], label='x1_test_normalized')
plt.plot(range(train_len, len(x_normalize)), x_normalize[train_len:, 1], label='x2_test_normalized')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# <img src='image/crop.png' width=600px />

# %%
print(len(x_normalize))
# Out:
# 1000

# %%
def truncate(x, feature_cols=range(3), target_cols=range(3), label_col=3, train_len=100, test_len=20):
    in_, out_, lbl = [], [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
        lbl.append(x[i+train_len, label_col])
        
        #print('{}\t~\t{} \t\t{}\t~\t{}'.format(i, i+train_len,i+train_len, i+train_len+test_len))
    return np.array(in_), np.array(out_), np.array(lbl)

# %%
X_in, X_out, lbl = truncate(x_normalize, feature_cols=range(3), target_cols=range(3), 
                            label_col=3, train_len=200, test_len=20)

print(X_in.shape, X_out.shape, lbl.shape)
# Out:
# (781, 200, 3) (781, 20, 3) (781,)

# %% [markdown]
# ```
# 0	~	200 		200	~	220
# 1	~	201 		201	~	221
# 2	~	202 		202	~	222
# 3	~	203 		203	~	223
# 4	~	204 		204	~	224
# ...
# 777	~	977 		977	~	997
# 778	~	978 		978	~	998
# 779	~	979 		979	~	999
# 780	~	980 		980	~	1000
# ```

# %%
len(x_normalize) - 200 - 20 + 1
# Out:
# 781

# %%
X_input_train = X_in[np.where(lbl==1)]
X_output_train = X_out[np.where(lbl==1)]
X_input_test = X_in[np.where(lbl==0)]
X_output_test = X_out[np.where(lbl==0)]
print(X_input_train.shape, X_output_train.shape)
print(X_input_test.shape, X_output_test.shape)
# Out:
# (600, 200, 3) (600, 20, 3)
# (181, 200, 3) (181, 20, 3)

# %% [markdown]
# ## Model 2: Seq2Seq LSTM Model with Luong Attention

# %%
n_hidden = 100
input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))

# %%
print(input_train)
print(output_train)
# Out:
# Tensor("input_1:0", shape=(None, 200, 2), dtype=float32)
# Tensor("input_2:0", shape=(None, 20, 2), dtype=float32)

# %% [markdown]
# ### The encoder LSTM
#
# This is slightly different from Model 1: besides returning the last hidden state and the last cell state, we also need to return the stacked hidden states for alignment score calculation.
#
# * return_sequences=False, return_state=False: return the last hidden state: state_h
# * return_sequences=False, return_state=True: return 3 arrays: state_h, state_h, state_c
# * return_sequences=True, return_state=True: return 3 arrays: stacked hidden states, last state_h, last state_c

# %%
n_hidden
# Out:
# 100

# %%
encoder_stack_h, encoder_last_h, encoder_last_c = LSTM(
    n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, 
    return_state=True, return_sequences=True)(input_train)

print(encoder_stack_h)
print(encoder_last_h)
print(encoder_last_c)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Tensor("lstm/transpose_1:0", shape=(None, 200, 100), dtype=float32)
# Tensor("lstm/while:4", shape=(None, 100), dtype=float32)
# Tensor("lstm/while:5", shape=(None, 100), dtype=float32)

# %%
#np.shape(a) #encoder_last_h1, encoder_last_h2, encoder_last_c

# %% [markdown]
# Next, we apply batch normalisation to avoid gradient explosion.

# %%
encoder_last_h = BatchNormalization(momentum=0.6)(encoder_last_h)
encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

# %% [markdown]
# Next, we make 20 copies of the last hidden state of encoder and use them as input to the decoder. The last cell state and the last hidden state of the encoder are also used as the initial states of decoder.

# %% [markdown]
# ### The Decoder LSTM

# %%
output_train.shape
# Out:
# TensorShape([None, 20, 2])

# %% [markdown]
# Next, we repeat the last hidden state of encoder 20 times, and use them as input to decoder LSTM.

# %%
decoder_input = RepeatVector(output_train.shape[1])(encoder_last_h) # make 20 copies of the last hidden state of encoder and use them as input to the decoder

# %%
print('{} ---- RepeatVector x {} ---> {}'.format(encoder_last_h.shape, output_train.shape[1],  decoder_input.shape))
# Out:
# (None, 100) ---- RepeatVector x 20 ---> (None, 20, 100)

# %% [markdown]
# We also need to get the stacked hidden state of de decoder for alignment score calculation.

# %%
decoder_stack_h = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2,
 return_state=False, return_sequences=True)(
 decoder_input, initial_state=[encoder_last_h, encoder_last_c])
print(decoder_stack_h)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Tensor("lstm_1/transpose_1:0", shape=(None, 20, 100), dtype=float32)

# %%
print(decoder_stack_h)
# Out:
# Tensor("lstm_1/transpose_1:0", shape=(None, 20, 100), dtype=float32)

# %% [markdown]
# ### Attention Layer

# %%
attention = dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
attention = Activation('softmax')(attention)
print(attention)
# Out:
# Tensor("activation/truediv:0", shape=(None, 20, 200), dtype=float32)

# %%
context = dot([attention, encoder_stack_h], axes=[2,1])
context = BatchNormalization(momentum=0.6)(context)
print(context)
# Out:
# Tensor("batch_normalization_2/batchnorm/add_1:0", shape=(None, 20, 100), dtype=float32)

# %%
decoder_combined_context = concatenate([context, decoder_stack_h])
print(decoder_combined_context)
# Out:
# Tensor("concatenate/concat:0", shape=(None, 20, 200), dtype=float32)

# %%
out = TimeDistributed(Dense(output_train.shape[2]))(decoder_combined_context)
print(out)
# Out:
# Tensor("time_distributed/Reshape_1:0", shape=(None, 20, 2), dtype=float32)

# %%
model = Model(inputs=input_train, outputs=out)
opt = Adam(lr=0.01, clipnorm=1)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 2)]     0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 200, 100), ( 41200       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 100)          400         lstm[0][1]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 20, 100)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100)          400         lstm[0][2]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 20, 100)      80400       repeat_vector[0][0]
#                                                                  batch_normalization[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 20, 200)      0           lstm_1[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 20, 200)      0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 20, 100)      0           activation[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 20, 100)      400         dot_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 200)      0           batch_normalization_2[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 20, 2)        402         concatenate[0][0]
# ==================================================================================================
# Total params: 123,202
# Trainable params: 122,602
# Non-trainable params: 600
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='image/model_plot_seq2seq_att.png', show_shapes=True, show_layer_names=True)

# %%
epc = 100
es = EarlyStopping(monitor='val_loss', mode='min', patience=50)

history = model.fit(X_input_train[:, :, :2], X_output_train[:, :, :2], validation_split=0.2, 
                    epochs=epc, verbose=1, callbacks=[es], 
                    batch_size=100)
train_mae = history.history['mae']
valid_mae = history.history['val_mae']
 
model.save('out/model_forecasting_seq2seq_luong.h5')
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 431ms/step - loss: 26.0313 - mae: 1.2442 - val_loss: 0.1475 - val_mae: 0.2902
# Epoch 2/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.1854 - mae: 0.3296 - val_loss: 0.1319 - val_mae: 0.2659
# Epoch 3/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.1399 - mae: 0.2780 - val_loss: 0.1323 - val_mae: 0.2731
# Epoch 4/100
# 5/5 [==============================] - 2s 376ms/step - loss: 0.1324 - mae: 0.2667 - val_loss: 0.1186 - val_mae: 0.2497
# Epoch 5/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.1245 - mae: 0.2579 - val_loss: 0.1105 - val_mae: 0.2421
# Epoch 6/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.1194 - mae: 0.2539 - val_loss: 0.1077 - val_mae: 0.2435
# Epoch 7/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.1148 - mae: 0.2503 - val_loss: 0.1038 - val_mae: 0.2410
# Epoch 8/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.1096 - mae: 0.2445 - val_loss: 0.0970 - val_mae: 0.2356
# Epoch 9/100
# 5/5 [==============================] - 2s 385ms/step - loss: 0.1049 - mae: 0.2391 - val_loss: 0.0901 - val_mae: 0.2238
# Epoch 10/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0985 - mae: 0.2324 - val_loss: 0.0834 - val_mae: 0.2143
# Epoch 11/100
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0980 - mae: 0.2284 - val_loss: 0.0827 - val_mae: 0.2106
# Epoch 12/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0911 - mae: 0.2225 - val_loss: 0.0754 - val_mae: 0.2062
# Epoch 13/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0896 - mae: 0.2196 - val_loss: 0.0725 - val_mae: 0.1988
# Epoch 14/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0848 - mae: 0.2144 - val_loss: 0.0757 - val_mae: 0.2080
# Epoch 15/100
# 5/5 [==============================] - 2s 367ms/step - loss: 0.0814 - mae: 0.2133 - val_loss: 0.0695 - val_mae: 0.1927
# Epoch 16/100
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0770 - mae: 0.2035 - val_loss: 0.0690 - val_mae: 0.1950
# Epoch 17/100
# 5/5 [==============================] - 2s 367ms/step - loss: 0.0729 - mae: 0.1986 - val_loss: 0.0736 - val_mae: 0.2004
# Epoch 18/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0677 - mae: 0.1924 - val_loss: 0.0590 - val_mae: 0.1900
# Epoch 19/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0631 - mae: 0.1850 - val_loss: 0.0572 - val_mae: 0.1757
# Epoch 20/100
# 5/5 [==============================] - 2s 352ms/step - loss: 0.0628 - mae: 0.1824 - val_loss: 0.0534 - val_mae: 0.1748
# Epoch 21/100
# 5/5 [==============================] - 2s 367ms/step - loss: 0.0669 - mae: 0.1874 - val_loss: 0.0537 - val_mae: 0.1807
# Epoch 22/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0563 - mae: 0.1751 - val_loss: 0.0457 - val_mae: 0.1634
# Epoch 23/100
# 5/5 [==============================] - 2s 365ms/step - loss: 0.0537 - mae: 0.1692 - val_loss: 0.0544 - val_mae: 0.1750
# Epoch 24/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0529 - mae: 0.1700 - val_loss: 0.0509 - val_mae: 0.1676
# Epoch 25/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0460 - mae: 0.1590 - val_loss: 0.0360 - val_mae: 0.1448
# Epoch 26/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0417 - mae: 0.1519 - val_loss: 0.0282 - val_mae: 0.1288
# Epoch 27/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0399 - mae: 0.1489 - val_loss: 0.0390 - val_mae: 0.1448
# Epoch 28/100
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0429 - mae: 0.1514 - val_loss: 0.0385 - val_mae: 0.1446
# Epoch 29/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0437 - mae: 0.1524 - val_loss: 0.0321 - val_mae: 0.1402
# Epoch 30/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0447 - mae: 0.1546 - val_loss: 0.0308 - val_mae: 0.1308
# Epoch 31/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0400 - mae: 0.1485 - val_loss: 0.0342 - val_mae: 0.1382
# Epoch 32/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0372 - mae: 0.1437 - val_loss: 0.0257 - val_mae: 0.1253
# Epoch 33/100
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0343 - mae: 0.1373 - val_loss: 0.0256 - val_mae: 0.1229
# Epoch 34/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0336 - mae: 0.1378 - val_loss: 0.0233 - val_mae: 0.1177
# Epoch 35/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0338 - mae: 0.1351 - val_loss: 0.0259 - val_mae: 0.1234
# Epoch 36/100
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0319 - mae: 0.1321 - val_loss: 0.0255 - val_mae: 0.1200
# Epoch 37/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0330 - mae: 0.1325 - val_loss: 0.0221 - val_mae: 0.1156
# Epoch 38/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0349 - mae: 0.1354 - val_loss: 0.0294 - val_mae: 0.1302
# Epoch 39/100
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0309 - mae: 0.1302 - val_loss: 0.0287 - val_mae: 0.1265
# Epoch 40/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0349 - mae: 0.1348 - val_loss: 0.0389 - val_mae: 0.1383
# Epoch 41/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0357 - mae: 0.1369 - val_loss: 0.0237 - val_mae: 0.1182
# Epoch 42/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0351 - mae: 0.1357 - val_loss: 0.0209 - val_mae: 0.1097
# Epoch 43/100
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0294 - mae: 0.1261 - val_loss: 0.0257 - val_mae: 0.1245
# Epoch 44/100
# 5/5 [==============================] - 2s 367ms/step - loss: 0.0292 - mae: 0.1255 - val_loss: 0.0209 - val_mae: 0.1087
# Epoch 45/100
# 5/5 [==============================] - 2s 365ms/step - loss: 0.0275 - mae: 0.1228 - val_loss: 0.0227 - val_mae: 0.1140
# Epoch 46/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0258 - mae: 0.1188 - val_loss: 0.0196 - val_mae: 0.1080
# Epoch 47/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0236 - mae: 0.1152 - val_loss: 0.0181 - val_mae: 0.1047
# Epoch 48/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0231 - mae: 0.1139 - val_loss: 0.0247 - val_mae: 0.1186
# Epoch 49/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0280 - mae: 0.1212 - val_loss: 0.0283 - val_mae: 0.1215
# Epoch 50/100
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0282 - mae: 0.1227 - val_loss: 0.0246 - val_mae: 0.1186
# Epoch 51/100
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0261 - mae: 0.1182 - val_loss: 0.0252 - val_mae: 0.1167
# Epoch 52/100
# 5/5 [==============================] - 2s 362ms/step - loss: 0.0252 - mae: 0.1168 - val_loss: 0.0289 - val_mae: 0.1293
# Epoch 53/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0279 - mae: 0.1216 - val_loss: 0.0184 - val_mae: 0.1035
# Epoch 54/100
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0237 - mae: 0.1135 - val_loss: 0.0218 - val_mae: 0.1170
# Epoch 55/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0236 - mae: 0.1132 - val_loss: 0.0233 - val_mae: 0.1151
# Epoch 56/100
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0235 - mae: 0.1124 - val_loss: 0.0184 - val_mae: 0.1003
# Epoch 57/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0241 - mae: 0.1149 - val_loss: 0.0280 - val_mae: 0.1213
# Epoch 58/100
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0258 - mae: 0.1181 - val_loss: 0.0203 - val_mae: 0.1087
# Epoch 59/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0228 - mae: 0.1116 - val_loss: 0.0216 - val_mae: 0.1124
# Epoch 60/100
# 5/5 [==============================] - 2s 364ms/step - loss: 0.0207 - mae: 0.1071 - val_loss: 0.0178 - val_mae: 0.1026
# Epoch 61/100
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0228 - mae: 0.1109 - val_loss: 0.0243 - val_mae: 0.1199
# Epoch 62/100
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0236 - mae: 0.1117 - val_loss: 0.0181 - val_mae: 0.1039
# Epoch 63/100
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0228 - mae: 0.1121 - val_loss: 0.0220 - val_mae: 0.1135
# Epoch 64/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0220 - mae: 0.1090 - val_loss: 0.0163 - val_mae: 0.1004
# Epoch 65/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0228 - mae: 0.1115 - val_loss: 0.0176 - val_mae: 0.1042
# Epoch 66/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0278 - mae: 0.1207 - val_loss: 0.0206 - val_mae: 0.1106
# Epoch 67/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0306 - mae: 0.1257 - val_loss: 0.0181 - val_mae: 0.1030
# Epoch 68/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0271 - mae: 0.1205 - val_loss: 0.0205 - val_mae: 0.1090
# Epoch 69/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0237 - mae: 0.1136 - val_loss: 0.0226 - val_mae: 0.1123
# Epoch 70/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0217 - mae: 0.1086 - val_loss: 0.0184 - val_mae: 0.1039
# Epoch 71/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0205 - mae: 0.1056 - val_loss: 0.0154 - val_mae: 0.0962
# Epoch 72/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0203 - mae: 0.1048 - val_loss: 0.0174 - val_mae: 0.1024
# Epoch 73/100
# 5/5 [==============================] - 2s 359ms/step - loss: 0.0237 - mae: 0.1135 - val_loss: 0.0154 - val_mae: 0.0959
# Epoch 74/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0233 - mae: 0.1115 - val_loss: 0.0194 - val_mae: 0.1093
# Epoch 75/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0255 - mae: 0.1153 - val_loss: 0.0214 - val_mae: 0.1094
# Epoch 76/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0230 - mae: 0.1110 - val_loss: 0.0210 - val_mae: 0.1073
# Epoch 77/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0254 - mae: 0.1143 - val_loss: 0.0256 - val_mae: 0.1167
# Epoch 78/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0228 - mae: 0.1101 - val_loss: 0.0191 - val_mae: 0.1037
# Epoch 79/100
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0201 - mae: 0.1047 - val_loss: 0.0221 - val_mae: 0.1102
# Epoch 80/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0207 - mae: 0.1056 - val_loss: 0.0148 - val_mae: 0.0950
# Epoch 81/100
# 5/5 [==============================] - 2s 357ms/step - loss: 0.0190 - mae: 0.1033 - val_loss: 0.0192 - val_mae: 0.1026
# Epoch 82/100
# 5/5 [==============================] - 2s 362ms/step - loss: 0.0188 - mae: 0.1017 - val_loss: 0.0157 - val_mae: 0.0981
# Epoch 83/100
# 5/5 [==============================] - 2s 357ms/step - loss: 0.0198 - mae: 0.1045 - val_loss: 0.0184 - val_mae: 0.1025
# Epoch 84/100
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0196 - mae: 0.1033 - val_loss: 0.0156 - val_mae: 0.0977
# Epoch 85/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0188 - mae: 0.1022 - val_loss: 0.0165 - val_mae: 0.0981
# Epoch 86/100
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0213 - mae: 0.1061 - val_loss: 0.0199 - val_mae: 0.1055
# Epoch 87/100
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0192 - mae: 0.1024 - val_loss: 0.0186 - val_mae: 0.1027
# Epoch 88/100
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0196 - mae: 0.1032 - val_loss: 0.0151 - val_mae: 0.0940
# Epoch 89/100
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0217 - mae: 0.1081 - val_loss: 0.0184 - val_mae: 0.1046
# Epoch 90/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0189 - mae: 0.1030 - val_loss: 0.0140 - val_mae: 0.0922
# Epoch 91/100
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0191 - mae: 0.1024 - val_loss: 0.0154 - val_mae: 0.0965
# Epoch 92/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0173 - mae: 0.0982 - val_loss: 0.0135 - val_mae: 0.0914
# Epoch 93/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0167 - mae: 0.0969 - val_loss: 0.0167 - val_mae: 0.0997
# Epoch 94/100
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0171 - mae: 0.0978 - val_loss: 0.0140 - val_mae: 0.0927
# Epoch 95/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0171 - mae: 0.0976 - val_loss: 0.0144 - val_mae: 0.0934
# Epoch 96/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0184 - mae: 0.1004 - val_loss: 0.0141 - val_mae: 0.0929
# Epoch 97/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0207 - mae: 0.1052 - val_loss: 0.0224 - val_mae: 0.1183
# Epoch 98/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0195 - mae: 0.1032 - val_loss: 0.0231 - val_mae: 0.1147
# Epoch 99/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0213 - mae: 0.1065 - val_loss: 0.0237 - val_mae: 0.1118
# Epoch 100/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0222 - mae: 0.1084 - val_loss: 0.0159 - val_mae: 0.0983

# %%
plt.figure(dpi=150)
plt.plot(train_mae, label='train mae'), 
plt.plot(valid_mae, label='validation mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.title('train vs. validation accuracy (mae)')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# ### Prediction
# The model prediction as well as the true values are unnormalised:

# %%
train_pred_detrend = model.predict(X_input_train[:, :, :2])*x_train_max[:2]
test_pred_detrend = model.predict(X_input_test[:, :, :2])*x_train_max[:2]
print(train_pred_detrend.shape, test_pred_detrend.shape)
# Out:
# (600, 20, 2) (181, 20, 2)

# %%
train_true_detrend = X_output_train[:, :, :2]*x_train_max[:2]
test_true_detrend = X_output_test[:, :, :2]*x_train_max[:2]
print(train_true_detrend.shape, test_true_detrend.shape)
# Out:
# (600, 20, 2) (181, 20, 2)

# %% [markdown]
# Then we combine the unnormalised outputs with their corresponding index, so that we can recover the trend.

# %%
train_pred_detrend = np.concatenate([train_pred_detrend, np.expand_dims(X_output_train[:, :, 2], axis=2)], axis=2)
test_pred_detrend = np.concatenate([test_pred_detrend, np.expand_dims(X_output_test[:, :, 2], axis=2)], axis=2)
print(train_pred_detrend.shape, test_pred_detrend.shape)
train_true_detrend = np.concatenate([train_true_detrend, np.expand_dims(X_output_train[:, :, 2], axis=2)], axis=2)
test_true_detrend = np.concatenate([test_true_detrend, np.expand_dims(X_output_test[:, :, 2], axis=2)], axis=2)
print(train_pred_detrend.shape, test_pred_detrend.shape)
# Out:
# (600, 20, 3) (181, 20, 3)
# (600, 20, 3) (181, 20, 3)

# %% [markdown]
# Next, we put all the outputs with recovered trend into a dictionary data_final.

# %%
data_final = dict()
for dt, lb in zip([train_pred_detrend, train_true_detrend, test_pred_detrend, test_true_detrend], 
                  ['train_pred', 'train_true', 'test_pred', 'test_true']):
    dt_x1 = dt[:, :, 0] + (dt[:, :, 2]**2)*x1_trend_param[0] + dt[:, :, 2]*x1_trend_param[1] + x1_trend_param[2]
    dt_x2 = dt[:, :, 1] + dt[:, :, 2]*x2_trend_param[0] + x2_trend_param[1]
    data_final[lb] = np.concatenate(
        [np.expand_dims(dt_x1, axis=2), np.expand_dims(dt_x2, axis=2)], axis=2)
    print(lb+': {}'.format(data_final[lb].shape))
# Out:
# train_pred: (600, 20, 2)
# train_true: (600, 20, 2)
# test_pred: (181, 20, 2)
# test_true: (181, 20, 2)

# %% [markdown]
# Just a quick check to see if the prediction value distribution is reasonable:

# %%
for lb in ['train', 'test']:
    plt.figure(figsize=(15, 4))
    plt.hist(data_final[lb+'_pred'].flatten(), bins=100, color='orange', alpha=0.5, label=lb+' pred')
    plt.hist(data_final[lb+'_true'].flatten(), bins=100, color='green', alpha=0.5, label=lb+' true')
    plt.legend()
    plt.title('value distribution: '+lb)
    plt.show()

# %% [markdown]
# The data distribution of prediction and true values are almost overlapped, so we are good.
#
# We can also plot MAE of all samples in time order, to see if there is clear pattern. The ideal situation is when line is random, otherwise it may indicate that the model is not sufficiently trained.

# %%
for lb in ['train', 'test']:
    MAE_overall = abs(data_final[lb+'_pred'] - data_final[lb+'_true']).mean()
    MAE_ = abs(data_final[lb+'_pred'] - data_final[lb+'_true']).mean(axis=(1, 2))
    plt.figure(figsize=(15, 3))
    plt.plot(MAE_)
    plt.title('MAE '+lb+': overall MAE = '+str(MAE_overall))
    plt.show()

# %% [markdown]
# Based on the above plots, we can say that there are still certain periodical pattens in both train and test MAE. Training for more epochs may lead to better results.
#
# Next we are going to check some random samples and see if the predicted lines and corresponding true lines are aligned.

# %%
ith_timestep = random.choice(range(data_final[lb+'_pred'].shape[1]))
print('{} among {}'.format(ith_timestep, data_final[lb+'_pred'].shape[1]))

plt.figure(figsize=(15, 5))
train_start_t = 0
test_start_t = data_final['train_pred'].shape[0]

for lb, tm, clrs in zip(['train', 'test'], [train_start_t, test_start_t], [['green', 'red'], ['blue', 'orange']]):
    for i, x_lbl in zip([0, 1], ['x1', 'x2']):
        plt.plot(range(tm, tm+data_final[lb+'_pred'].shape[0]), 
                 data_final[lb+'_pred'][:, ith_timestep, i], 
                 linestyle='--', linewidth=1, color=clrs[0], label='pred '+x_lbl)
        plt.plot(range(tm, tm+data_final[lb+'_pred'].shape[0]), 
                 data_final[lb+'_true'][:, ith_timestep, i], 
                 linestyle='-', linewidth=1, color=clrs[1], label='true '+x_lbl)
    
plt.title('{}th time step in all samples'.format(ith_timestep))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=8)
plt.show()
# Out:
# 13 among 20

# %% [markdown]
# Take a closer look at the prediction on test set:

# %%
lb = 'test'
plt.figure(figsize=(15, 5))
for i, x_lbl, clr in zip([0, 1], ['x1', 'x2'], ['green', 'blue']):
    plt.plot(data_final[lb+'_pred'][:, ith_timestep, i], linestyle='--', color=clr, label='pred '+x_lbl)
    plt.plot(data_final[lb+'_true'][:, ith_timestep, i], linestyle='-', color=clr, label='true '+x_lbl)
plt.title('({}): {}th time step in all samples'.format(lb, ith_timestep))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# ### References
# * Huangwei Wieniawska, Building Seq2Seq LSTM with Luong Attention in Keras for Time Series Forecasting, 2020
# https://levelup.gitconnected.com/building-seq2seq-lstm-with-luong-attention-in-keras-for-time-series-forecasting-1ee00958decb
#
# * 양방향 LSTM과 어텐션 메커니즘(BiLSTM with Attention mechanism), https://wikidocs.net/48920
