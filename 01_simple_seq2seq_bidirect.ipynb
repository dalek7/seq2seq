# %%
import random
import numpy as np
import matplotlib.pyplot as plt

import pickle as pkl
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Input, BatchNormalization, \
    multiply, concatenate, Flatten, Activation, dot, Bidirectional, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping
import pydot as pyd

# %%
print(tensorflow.__version__)
print(tensorflow.keras.__version__)
# Out:
# 2.3.0
# 2.4.0

# %% [markdown]
# ### Create Some Data

# %%
n_ = 1000
t = np.linspace(0, 50*np.pi, n_)
# pattern + trend + noise
x1 = sum([20*np.sin(i*t+np.pi) for i in range(5)]) + 0.01*(t**2) + np.random.normal(0, 6, n_)
x2 = sum([15*np.sin(2*i*t+np.pi) for i in range(5)]) + 0.5*t + np.random.normal(0, 6, n_)
plt.figure(figsize=(15, 4))
plt.plot(range(len(x1)), x1, label='x1')
plt.plot(range(len(x2)), x2, label='x2')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# ### Split sequences to 80% train set and 20% test set
# We’ve just created two sequences, x1 and x2, by combining sin waves, trend, and random noise. Next we will preprocess x1 and x2.

# %%
train_ratio = 0.8
train_len = int(train_ratio * t.shape[0])
print(train_len)
print(t.shape[0])
# Out:
# 800
# 1000

# %% [markdown]
# ### Detrending
# It is not a must to detrend time series. However stationary time series will make model training much easier. There are many ways to detrend time series, such as taking difference of sequence with its lag1. Here for the simplicity, we assume the order of trend is known and we are just going to simply fit separate trend lines to x1 and x2, and then subtract the trend from the corresponding original sequence.
#
# We will create index number of each position in the sequence, for easier detrending and trend recover.

# %%
x_index = np.array(range(len(t)))

# %% [markdown]
# Here we will use np.polyfit to complete this small task. Note that only the first 800 data points are used to fit the trend lines, this is because we want to avoid data leak.

# %%
x1_trend_param = np.polyfit(x_index[:train_len], x1[:train_len], 2)
x2_trend_param = np.polyfit(x_index[:train_len], x2[:train_len], 1)
print(x1_trend_param)
print(x2_trend_param)
# Out:
# [ 2.41352521e-04  9.30405488e-03 -2.71647982e+00]
# [ 0.08096103 -0.84858161]

# %%
x1_trend = (x_index**2)*x1_trend_param[0]+x_index*x1_trend_param[1]+x1_trend_param[2]
x2_trend = x_index*x2_trend_param[0]+x2_trend_param[1]

# %%
plt.figure(figsize=(15, 4))
plt.plot(range(len(x1)), x1, label='x1')
plt.plot(range(len(x1_trend)), x1_trend, linestyle='--', label='x1_trend')
plt.plot(range(len(x2)), x2, label='x2')
plt.plot(range(len(x2_trend)), x2_trend, linestyle='--', label='x2_trend')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %%
x1_detrend = x1 - x1_trend
x2_detrend = x2 - x2_trend
plt.figure(figsize=(15, 4))
plt.plot(range(len(x1_detrend)), x1_detrend, label='x2_detrend')
plt.plot(range(len(x2_detrend)), x2_detrend, label='x2_detrend')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# * the first column is the detrended x1
# * the second column is the detrended x2
# * the third column is the index
# * the fourth column is the label (1 for train set and 0 for test set)

# %%
x_lbl = np.column_stack([x1_detrend, x2_detrend, x_index, [1]*train_len+[0]*(len(x_index)-train_len)])
print(x_lbl.shape)
print(x_lbl)
# Out:
# (1000, 4)
# [[-8.75001526e+00 -6.95369124e+00  0.00000000e+00  1.00000000e+00]
#  [-2.14513419e+01 -3.81146206e+01  1.00000000e+00  1.00000000e+00]
#  [-6.05555366e+01 -4.42245633e+01  2.00000000e+00  1.00000000e+00]
#  ...
#  [ 5.06403041e+01  4.47168558e+01  9.97000000e+02  0.00000000e+00]
#  [ 2.32538311e+01  3.12038025e+01  9.98000000e+02  0.00000000e+00]
#  [-3.01803143e+00 -9.32054698e-01  9.99000000e+02  0.00000000e+00]]

# %% [markdown]
# ### Normalize
# Normalisation can help model avoid favouring large features while ignoring very small features. Here we can just simply normalise x1 and x2 by dividing the corresponding maximum values in train set.

# %%
x_train_max = x_lbl[x_lbl[:, 3]==1, :2].max(axis=0)
x_train_max = x_train_max.tolist()+[1]*2  # only normalize for the first 2 columns
print(x_train_max)
# Out:
# [78.01541866625195, 59.803339792577454, 1, 1]

# %%
x_normalize = np.divide(x_lbl, x_train_max)

# %%
plt.figure(figsize=(15, 4))
plt.plot(range(train_len), x_normalize[:train_len, 0], label='x1_train_normalized')
plt.plot(range(train_len), x_normalize[:train_len, 1], label='x2_train_normalized')
plt.plot(range(train_len, len(x_normalize)), x_normalize[train_len:, 0], label='x1_test_normalized')
plt.plot(range(train_len, len(x_normalize)), x_normalize[train_len:, 1], label='x2_test_normalized')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# <img src='image/crop.png' width=600px />

# %%
print(len(x_normalize))
# Out:
# 1000

# %%
def truncate(x, feature_cols=range(3), target_cols=range(3), label_col=3, train_len=100, test_len=20):
    in_, out_, lbl = [], [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
        lbl.append(x[i+train_len, label_col])
        
        #print('{}\t~\t{} \t\t{}\t~\t{}'.format(i, i+train_len,i+train_len, i+train_len+test_len))
    return np.array(in_), np.array(out_), np.array(lbl)

# %%
X_in, X_out, lbl = truncate(x_normalize, feature_cols=range(3), target_cols=range(3), 
                            label_col=3, train_len=200, test_len=20)

print(X_in.shape, X_out.shape, lbl.shape)
# Out:
# (781, 200, 3) (781, 20, 3) (781,)

# %% [markdown]
# ```
# 0	~	200 		200	~	220
# 1	~	201 		201	~	221
# 2	~	202 		202	~	222
# 3	~	203 		203	~	223
# 4	~	204 		204	~	224
# ...
# 777	~	977 		977	~	997
# 778	~	978 		978	~	998
# 779	~	979 		979	~	999
# 780	~	980 		980	~	1000
# ```

# %%
len(x_normalize) - 200 - 20 + 1
# Out:
# 781

# %%
X_input_train = X_in[np.where(lbl==1)]
X_output_train = X_out[np.where(lbl==1)]
X_input_test = X_in[np.where(lbl==0)]
X_output_test = X_out[np.where(lbl==0)]
print(X_input_train.shape, X_output_train.shape)
print(X_input_test.shape, X_output_test.shape)
# Out:
# (600, 200, 3) (600, 20, 3)
# (181, 200, 3) (181, 20, 3)

# %% [markdown]
# ## Model 1: Simple Seq2Seq LSTM Model

# %%
n_hidden = 100
input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))

# %%
print(input_train)
print(output_train)
# Out:
# Tensor("input_1:0", shape=(None, 200, 2), dtype=float32)
# Tensor("input_2:0", shape=(None, 20, 2), dtype=float32)

# %% [markdown]
# ### The encoder LSTM
#
# * return_sequences=False, return_state=False: return the last hidden state: state_h
# * return_sequences=False, return_state=True: return 3 arrays: state_h, state_h, state_c

# %%
n_hidden
# Out:
# 100

# %%
use_bidirectional = True

# %%
if not use_bidirectional: # not using bidirectional
    encoder_last_h1, encoder_last_h2, encoder_last_c = LSTM( #  (lstm, state_h, state_c).
     n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, 
     return_sequences=False, return_state=True)(input_train)
    
else: #https://stackoverflow.com/a/49326310
    lstm, forward_h, forward_c, backward_h, backward_c = Bidirectional(LSTM(
 n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, 
 return_sequences=False, return_state=True))(input_train) 
        
    print(lstm.shape, forward_h.shape, forward_c.shape, backward_h.shape, backward_c.shape)
    # 순방향 LSTM의 은닉 상태와 셀 상태를 forward_h, forward_c에 저장하고, 
    # 역방향 LSTM의 은닉 상태와 셀 상태를 backward_h, backward_c에 저장
    
    # 순방향 LSTM의 은닉 상태와 셀상태를 forward_h, forward_c에 저장하고, 역방향 LSTM의 은닉 상태와 셀 상태를 backward_h, backward_c에 저장하면 됨
    state_h = Concatenate()([forward_h, backward_h])
    state_c = Concatenate()([forward_c, backward_c])
    
    print(state_h.shape)
    print(state_c.shape)
    
    encoder_last_h1 = lstm
    encoder_last_h2 = state_h # not using ?
    encoder_last_c = state_c
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# (None, 200) (None, 100) (None, 100) (None, 100) (None, 100)
# (None, 200)
# (None, 200)

# %%
#np.shape(a) #encoder_last_h1, encoder_last_h2, encoder_last_c

# %%
print(encoder_last_h1)
print(encoder_last_h2)
print(encoder_last_c)
# Out:
# Tensor("bidirectional/concat:0", shape=(None, 200), dtype=float32)
# Tensor("concatenate/concat:0", shape=(None, 200), dtype=float32)
# Tensor("concatenate_1/concat:0", shape=(None, 200), dtype=float32)

# %% [markdown]
# Batch normalisation is added because we want to avoid gradient explosion caused by the activation function ELU in the encoder.

# %%
encoder_last_h1 = BatchNormalization(momentum=0.6)(encoder_last_h1)
encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

# %% [markdown]
# Next, we make 20 copies of the last hidden state of encoder and use them as input to the decoder. The last cell state and the last hidden state of the encoder are also used as the initial states of decoder.

# %%
output_train.shape
# Out:
# TensorShape([None, 20, 2])

# %%
decoder = RepeatVector(output_train.shape[1])(encoder_last_h1) # make 20 copies of the last hidden state of encoder and use them as input to the decoder

# %%
print('{} ---- RepeatVector x {} ---> {}'.format(encoder_last_h1.shape, output_train.shape[1],  decoder.shape))
# Out:
# (None, 200) ---- RepeatVector x 20 ---> (None, 20, 200)

# %%
if not use_bidirectional: # not using bidirectional
    decoder = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(
        decoder, initial_state=[encoder_last_h1, encoder_last_c])
else:
    decoder = LSTM(n_hidden*2, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(
        decoder, initial_state=[encoder_last_h1, encoder_last_c])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
print(decoder)
# Out:
# Tensor("lstm_1/transpose_1:0", shape=(None, 20, 200), dtype=float32)

# %%
out = TimeDistributed(Dense(output_train.shape[2]))(decoder)
print(out)
# Out:
# Tensor("time_distributed/Reshape_1:0", shape=(None, 20, 2), dtype=float32)

# %%
model = Model(inputs=input_train, outputs=out)
opt = Adam(lr=0.01, clipnorm=1)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 2)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 200), (None, 82400       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200)          800         bidirectional[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 200)          0           bidirectional[0][2]
#                                                                  bidirectional[0][4]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 20, 200)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200)          800         concatenate_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 20, 200)      320800      repeat_vector[0][0]
#                                                                  batch_normalization[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 20, 2)        402         lstm_1[0][0]
# ==================================================================================================
# Total params: 405,202
# Trainable params: 404,402
# Non-trainable params: 800
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='image/model_plot_seq2seq.png', show_shapes=True, show_layer_names=True)

# %%
epc = 100
es = EarlyStopping(monitor='val_loss', mode='min', patience=50)

history = model.fit(X_input_train[:, :, :2], X_output_train[:, :, :2], validation_split=0.2, 
                    epochs=epc, verbose=1, callbacks=[es], 
                    batch_size=100)
train_mae = history.history['mae']
valid_mae = history.history['val_mae']
 
model.save('model_forecasting_seq2seq.h5')
# Out:
# Epoch 1/100
# 5/5 [==============================] - 4s 806ms/step - loss: 137.6843 - mae: 3.9361 - val_loss: 0.1443 - val_mae: 0.2835
# Epoch 2/100
# 5/5 [==============================] - 3s 690ms/step - loss: 0.3602 - mae: 0.4511 - val_loss: 0.1459 - val_mae: 0.2850
# Epoch 3/100
# 5/5 [==============================] - 4s 702ms/step - loss: 0.1689 - mae: 0.3122 - val_loss: 0.1191 - val_mae: 0.2553
# Epoch 4/100
# 5/5 [==============================] - 3s 698ms/step - loss: 0.1263 - mae: 0.2648 - val_loss: 0.1079 - val_mae: 0.2411
# Epoch 5/100
# 5/5 [==============================] - 3s 700ms/step - loss: 0.1148 - mae: 0.2505 - val_loss: 0.1031 - val_mae: 0.2370
# Epoch 6/100
# 5/5 [==============================] - 3s 700ms/step - loss: 0.1076 - mae: 0.2404 - val_loss: 0.0943 - val_mae: 0.2248
# Epoch 7/100
# 5/5 [==============================] - 3s 667ms/step - loss: 0.1014 - mae: 0.2335 - val_loss: 0.0879 - val_mae: 0.2181
# Epoch 8/100
# 5/5 [==============================] - 3s 687ms/step - loss: 0.0951 - mae: 0.2262 - val_loss: 0.0827 - val_mae: 0.2088
# Epoch 9/100
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0945 - mae: 0.2241 - val_loss: 0.0835 - val_mae: 0.2091
# Epoch 10/100
# 5/5 [==============================] - 4s 704ms/step - loss: 0.0895 - mae: 0.2193 - val_loss: 0.0744 - val_mae: 0.1992
# Epoch 11/100
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0818 - mae: 0.2101 - val_loss: 0.0658 - val_mae: 0.1881
# Epoch 12/100
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0762 - mae: 0.2036 - val_loss: 0.0762 - val_mae: 0.1962
# Epoch 13/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0761 - mae: 0.2004 - val_loss: 0.0689 - val_mae: 0.1867
# Epoch 14/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0701 - mae: 0.1925 - val_loss: 0.0580 - val_mae: 0.1766
# Epoch 15/100
# 5/5 [==============================] - 3s 684ms/step - loss: 0.0654 - mae: 0.1883 - val_loss: 0.0514 - val_mae: 0.1708
# Epoch 16/100
# 5/5 [==============================] - 3s 688ms/step - loss: 0.0613 - mae: 0.1822 - val_loss: 0.0482 - val_mae: 0.1641
# Epoch 17/100
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0674 - mae: 0.1880 - val_loss: 0.0571 - val_mae: 0.1692
# Epoch 18/100
# 5/5 [==============================] - 4s 702ms/step - loss: 0.0614 - mae: 0.1808 - val_loss: 0.0460 - val_mae: 0.1583
# Epoch 19/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0539 - mae: 0.1694 - val_loss: 0.0409 - val_mae: 0.1523
# Epoch 20/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0523 - mae: 0.1678 - val_loss: 0.0356 - val_mae: 0.1411
# Epoch 21/100
# 5/5 [==============================] - 3s 692ms/step - loss: 0.0477 - mae: 0.1603 - val_loss: 0.0372 - val_mae: 0.1458
# Epoch 22/100
# 5/5 [==============================] - 3s 681ms/step - loss: 0.0523 - mae: 0.1658 - val_loss: 0.0324 - val_mae: 0.1368
# Epoch 23/100
# 5/5 [==============================] - 3s 685ms/step - loss: 0.0492 - mae: 0.1615 - val_loss: 0.0681 - val_mae: 0.1869
# Epoch 24/100
# 5/5 [==============================] - 3s 676ms/step - loss: 0.0574 - mae: 0.1732 - val_loss: 0.0415 - val_mae: 0.1515
# Epoch 25/100
# 5/5 [==============================] - 3s 692ms/step - loss: 0.0431 - mae: 0.1538 - val_loss: 0.0281 - val_mae: 0.1302
# Epoch 26/100
# 5/5 [==============================] - 3s 681ms/step - loss: 0.0406 - mae: 0.1475 - val_loss: 0.0376 - val_mae: 0.1395
# Epoch 27/100
# 5/5 [==============================] - 3s 660ms/step - loss: 0.0432 - mae: 0.1509 - val_loss: 0.0473 - val_mae: 0.1552
# Epoch 28/100
# 5/5 [==============================] - 3s 673ms/step - loss: 0.0565 - mae: 0.1676 - val_loss: 0.0379 - val_mae: 0.1479
# Epoch 29/100
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0465 - mae: 0.1608 - val_loss: 0.0354 - val_mae: 0.1426
# Epoch 30/100
# 5/5 [==============================] - 3s 683ms/step - loss: 0.0389 - mae: 0.1460 - val_loss: 0.0262 - val_mae: 0.1262
# Epoch 31/100
# 5/5 [==============================] - 3s 679ms/step - loss: 0.0333 - mae: 0.1373 - val_loss: 0.0229 - val_mae: 0.1195
# Epoch 32/100
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0318 - mae: 0.1340 - val_loss: 0.0230 - val_mae: 0.1194
# Epoch 33/100
# 5/5 [==============================] - 3s 675ms/step - loss: 0.0320 - mae: 0.1331 - val_loss: 0.0210 - val_mae: 0.1127
# Epoch 34/100
# 5/5 [==============================] - 3s 696ms/step - loss: 0.0316 - mae: 0.1324 - val_loss: 0.0227 - val_mae: 0.1193
# Epoch 35/100
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0303 - mae: 0.1290 - val_loss: 0.0204 - val_mae: 0.1109
# Epoch 36/100
# 5/5 [==============================] - 3s 687ms/step - loss: 0.0294 - mae: 0.1266 - val_loss: 0.0167 - val_mae: 0.1016
# Epoch 37/100
# 5/5 [==============================] - 3s 691ms/step - loss: 0.0261 - mae: 0.1203 - val_loss: 0.0184 - val_mae: 0.1057
# Epoch 38/100
# 5/5 [==============================] - 3s 687ms/step - loss: 0.0237 - mae: 0.1159 - val_loss: 0.0181 - val_mae: 0.1043
# Epoch 39/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0248 - mae: 0.1169 - val_loss: 0.0161 - val_mae: 0.0993
# Epoch 40/100
# 5/5 [==============================] - 3s 698ms/step - loss: 0.0250 - mae: 0.1176 - val_loss: 0.0168 - val_mae: 0.1033
# Epoch 41/100
# 5/5 [==============================] - 3s 700ms/step - loss: 0.0252 - mae: 0.1171 - val_loss: 0.0173 - val_mae: 0.0999
# Epoch 42/100
# 5/5 [==============================] - 3s 693ms/step - loss: 0.0236 - mae: 0.1154 - val_loss: 0.0144 - val_mae: 0.0954
# Epoch 43/100
# 5/5 [==============================] - 3s 687ms/step - loss: 0.0220 - mae: 0.1116 - val_loss: 0.0213 - val_mae: 0.1069
# Epoch 44/100
# 5/5 [==============================] - 3s 695ms/step - loss: 0.0251 - mae: 0.1171 - val_loss: 0.0189 - val_mae: 0.1075
# Epoch 45/100
# 5/5 [==============================] - 3s 659ms/step - loss: 0.0230 - mae: 0.1133 - val_loss: 0.0175 - val_mae: 0.1016
# Epoch 46/100
# 5/5 [==============================] - 3s 687ms/step - loss: 0.0234 - mae: 0.1146 - val_loss: 0.0168 - val_mae: 0.1023
# Epoch 47/100
# 5/5 [==============================] - 3s 698ms/step - loss: 0.0236 - mae: 0.1146 - val_loss: 0.0165 - val_mae: 0.0992
# Epoch 48/100
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0209 - mae: 0.1087 - val_loss: 0.0181 - val_mae: 0.1052
# Epoch 49/100
# 5/5 [==============================] - 3s 695ms/step - loss: 0.0257 - mae: 0.1179 - val_loss: 0.0357 - val_mae: 0.1350
# Epoch 50/100
# 5/5 [==============================] - 3s 684ms/step - loss: 0.0308 - mae: 0.1264 - val_loss: 0.0209 - val_mae: 0.1119
# Epoch 51/100
# 5/5 [==============================] - 3s 690ms/step - loss: 0.0285 - mae: 0.1242 - val_loss: 0.0141 - val_mae: 0.0946
# Epoch 52/100
# 5/5 [==============================] - 3s 664ms/step - loss: 0.0226 - mae: 0.1125 - val_loss: 0.0154 - val_mae: 0.0953
# Epoch 53/100
# 5/5 [==============================] - 3s 685ms/step - loss: 0.0201 - mae: 0.1072 - val_loss: 0.0135 - val_mae: 0.0915
# Epoch 54/100
# 5/5 [==============================] - 4s 705ms/step - loss: 0.0184 - mae: 0.1038 - val_loss: 0.0129 - val_mae: 0.0889
# Epoch 55/100
# 5/5 [==============================] - 4s 704ms/step - loss: 0.0184 - mae: 0.1029 - val_loss: 0.0126 - val_mae: 0.0880
# Epoch 56/100
# 5/5 [==============================] - 3s 687ms/step - loss: 0.0189 - mae: 0.1043 - val_loss: 0.0138 - val_mae: 0.0935
# Epoch 57/100
# 5/5 [==============================] - 3s 672ms/step - loss: 0.0181 - mae: 0.1022 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 58/100
# 5/5 [==============================] - 4s 702ms/step - loss: 0.0181 - mae: 0.1020 - val_loss: 0.0130 - val_mae: 0.0890
# Epoch 59/100
# 5/5 [==============================] - 3s 690ms/step - loss: 0.0183 - mae: 0.1029 - val_loss: 0.0119 - val_mae: 0.0866
# Epoch 60/100
# 5/5 [==============================] - 3s 672ms/step - loss: 0.0175 - mae: 0.1010 - val_loss: 0.0141 - val_mae: 0.0955
# Epoch 61/100
# 5/5 [==============================] - 3s 684ms/step - loss: 0.0200 - mae: 0.1064 - val_loss: 0.0158 - val_mae: 0.0967
# Epoch 62/100
# 5/5 [==============================] - 3s 695ms/step - loss: 0.0181 - mae: 0.1016 - val_loss: 0.0120 - val_mae: 0.0873
# Epoch 63/100
# 5/5 [==============================] - 3s 690ms/step - loss: 0.0185 - mae: 0.1024 - val_loss: 0.0153 - val_mae: 0.0953
# Epoch 64/100
# 5/5 [==============================] - 3s 684ms/step - loss: 0.0177 - mae: 0.1012 - val_loss: 0.0124 - val_mae: 0.0896
# Epoch 65/100
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0170 - mae: 0.1004 - val_loss: 0.0128 - val_mae: 0.0875
# Epoch 66/100
# 5/5 [==============================] - 3s 672ms/step - loss: 0.0165 - mae: 0.0977 - val_loss: 0.0118 - val_mae: 0.0869
# Epoch 67/100
# 5/5 [==============================] - 3s 691ms/step - loss: 0.0172 - mae: 0.0997 - val_loss: 0.0113 - val_mae: 0.0844
# Epoch 68/100
# 5/5 [==============================] - 3s 690ms/step - loss: 0.0168 - mae: 0.0983 - val_loss: 0.0127 - val_mae: 0.0897
# Epoch 69/100
# 5/5 [==============================] - 3s 692ms/step - loss: 0.0173 - mae: 0.1004 - val_loss: 0.0155 - val_mae: 0.0969
# Epoch 70/100
# 5/5 [==============================] - 4s 700ms/step - loss: 0.0213 - mae: 0.1080 - val_loss: 0.0165 - val_mae: 0.0983
# Epoch 71/100
# 5/5 [==============================] - 4s 704ms/step - loss: 0.0216 - mae: 0.1088 - val_loss: 0.0151 - val_mae: 0.0948
# Epoch 72/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0196 - mae: 0.1052 - val_loss: 0.0120 - val_mae: 0.0884
# Epoch 73/100
# 5/5 [==============================] - 3s 690ms/step - loss: 0.0170 - mae: 0.0999 - val_loss: 0.0130 - val_mae: 0.0902
# Epoch 74/100
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0185 - mae: 0.1023 - val_loss: 0.0120 - val_mae: 0.0877
# Epoch 75/100
# 5/5 [==============================] - 4s 709ms/step - loss: 0.0166 - mae: 0.0987 - val_loss: 0.0114 - val_mae: 0.0858
# Epoch 76/100
# 5/5 [==============================] - 3s 688ms/step - loss: 0.0171 - mae: 0.0988 - val_loss: 0.0125 - val_mae: 0.0875
# Epoch 77/100
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0170 - mae: 0.0984 - val_loss: 0.0127 - val_mae: 0.0900
# Epoch 78/100
# 5/5 [==============================] - 3s 679ms/step - loss: 0.0169 - mae: 0.0986 - val_loss: 0.0151 - val_mae: 0.0957
# Epoch 79/100
# 5/5 [==============================] - 3s 658ms/step - loss: 0.0173 - mae: 0.0986 - val_loss: 0.0113 - val_mae: 0.0855
# Epoch 80/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0167 - mae: 0.0980 - val_loss: 0.0144 - val_mae: 0.0936
# Epoch 81/100
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0177 - mae: 0.1001 - val_loss: 0.0178 - val_mae: 0.1034
# Epoch 82/100
# 5/5 [==============================] - 3s 675ms/step - loss: 0.0195 - mae: 0.1041 - val_loss: 0.0149 - val_mae: 0.0943
# Epoch 83/100
# 5/5 [==============================] - 3s 685ms/step - loss: 0.0166 - mae: 0.0978 - val_loss: 0.0113 - val_mae: 0.0848
# Epoch 84/100
# 5/5 [==============================] - 3s 685ms/step - loss: 0.0158 - mae: 0.0955 - val_loss: 0.0123 - val_mae: 0.0885
# Epoch 85/100
# 5/5 [==============================] - 3s 684ms/step - loss: 0.0156 - mae: 0.0948 - val_loss: 0.0115 - val_mae: 0.0850
# Epoch 86/100
# 5/5 [==============================] - 3s 683ms/step - loss: 0.0161 - mae: 0.0965 - val_loss: 0.0116 - val_mae: 0.0853
# Epoch 87/100
# 5/5 [==============================] - 3s 681ms/step - loss: 0.0158 - mae: 0.0955 - val_loss: 0.0128 - val_mae: 0.0895
# Epoch 88/100
# 5/5 [==============================] - 3s 663ms/step - loss: 0.0168 - mae: 0.0979 - val_loss: 0.0117 - val_mae: 0.0867
# Epoch 89/100
# 5/5 [==============================] - 3s 676ms/step - loss: 0.0162 - mae: 0.0967 - val_loss: 0.0120 - val_mae: 0.0870
# Epoch 90/100
# 5/5 [==============================] - 4s 703ms/step - loss: 0.0160 - mae: 0.0959 - val_loss: 0.0133 - val_mae: 0.0912
# Epoch 91/100
# 5/5 [==============================] - 3s 675ms/step - loss: 0.0178 - mae: 0.1002 - val_loss: 0.0161 - val_mae: 0.0982
# Epoch 92/100
# 5/5 [==============================] - 3s 677ms/step - loss: 0.0176 - mae: 0.0991 - val_loss: 0.0136 - val_mae: 0.0925
# Epoch 93/100
# 5/5 [==============================] - 3s 660ms/step - loss: 0.0176 - mae: 0.0997 - val_loss: 0.0120 - val_mae: 0.0863
# Epoch 94/100
# 5/5 [==============================] - 3s 672ms/step - loss: 0.0211 - mae: 0.1078 - val_loss: 0.0163 - val_mae: 0.0990
# Epoch 95/100
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0189 - mae: 0.1030 - val_loss: 0.0146 - val_mae: 0.0921
# Epoch 96/100
# 5/5 [==============================] - 3s 671ms/step - loss: 0.0157 - mae: 0.0955 - val_loss: 0.0167 - val_mae: 0.0987
# Epoch 97/100
# 5/5 [==============================] - 3s 692ms/step - loss: 0.0155 - mae: 0.0945 - val_loss: 0.0111 - val_mae: 0.0831
# Epoch 98/100
# 5/5 [==============================] - 3s 688ms/step - loss: 0.0152 - mae: 0.0947 - val_loss: 0.0124 - val_mae: 0.0892
# Epoch 99/100
# 5/5 [==============================] - 3s 681ms/step - loss: 0.0166 - mae: 0.0980 - val_loss: 0.0123 - val_mae: 0.0885
# Epoch 100/100
# 5/5 [==============================] - 3s 683ms/step - loss: 0.0156 - mae: 0.0953 - val_loss: 0.0115 - val_mae: 0.0856

# %%
plt.figure(dpi=150)
plt.plot(train_mae, label='train mae'), 
plt.plot(valid_mae, label='validation mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.title('train vs. validation accuracy (mae)')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# ### Prediction
# The model prediction as well as the true values are unnormalised:

# %%
train_pred_detrend = model.predict(X_input_train[:, :, :2])*x_train_max[:2]
test_pred_detrend = model.predict(X_input_test[:, :, :2])*x_train_max[:2]
print(train_pred_detrend.shape, test_pred_detrend.shape)
# Out:
# (600, 20, 2) (181, 20, 2)

# %%
train_true_detrend = X_output_train[:, :, :2]*x_train_max[:2]
test_true_detrend = X_output_test[:, :, :2]*x_train_max[:2]
print(train_true_detrend.shape, test_true_detrend.shape)
# Out:
# (600, 20, 2) (181, 20, 2)

# %% [markdown]
# Then we combine the unnormalised outputs with their corresponding index, so that we can recover the trend.

# %%
train_pred_detrend = np.concatenate([train_pred_detrend, np.expand_dims(X_output_train[:, :, 2], axis=2)], axis=2)
test_pred_detrend = np.concatenate([test_pred_detrend, np.expand_dims(X_output_test[:, :, 2], axis=2)], axis=2)
print(train_pred_detrend.shape, test_pred_detrend.shape)
train_true_detrend = np.concatenate([train_true_detrend, np.expand_dims(X_output_train[:, :, 2], axis=2)], axis=2)
test_true_detrend = np.concatenate([test_true_detrend, np.expand_dims(X_output_test[:, :, 2], axis=2)], axis=2)
print(train_pred_detrend.shape, test_pred_detrend.shape)
# Out:
# (600, 20, 3) (181, 20, 3)
# (600, 20, 3) (181, 20, 3)

# %% [markdown]
# Next, we put all the outputs with recovered trend into a dictionary data_final.

# %%
data_final = dict()
for dt, lb in zip([train_pred_detrend, train_true_detrend, test_pred_detrend, test_true_detrend], 
                  ['train_pred', 'train_true', 'test_pred', 'test_true']):
    dt_x1 = dt[:, :, 0] + (dt[:, :, 2]**2)*x1_trend_param[0] + dt[:, :, 2]*x1_trend_param[1] + x1_trend_param[2]
    dt_x2 = dt[:, :, 1] + dt[:, :, 2]*x2_trend_param[0] + x2_trend_param[1]
    data_final[lb] = np.concatenate(
        [np.expand_dims(dt_x1, axis=2), np.expand_dims(dt_x2, axis=2)], axis=2)
    print(lb+': {}'.format(data_final[lb].shape))
# Out:
# train_pred: (600, 20, 2)
# train_true: (600, 20, 2)
# test_pred: (181, 20, 2)
# test_true: (181, 20, 2)

# %% [markdown]
# Just a quick check to see if the prediction value distribution is reasonable:

# %%
for lb in ['train', 'test']:
    plt.figure(figsize=(15, 4))
    plt.hist(data_final[lb+'_pred'].flatten(), bins=100, color='orange', alpha=0.5, label=lb+' pred')
    plt.hist(data_final[lb+'_true'].flatten(), bins=100, color='green', alpha=0.5, label=lb+' true')
    plt.legend()
    plt.title('value distribution: '+lb)
    plt.show()

# %% [markdown]
# The data distribution of prediction and true values are almost overlapped, so we are good.
#
# We can also plot MAE of all samples in time order, to see if there is clear pattern. The ideal situation is when line is random, otherwise it may indicate that the model is not sufficiently trained.

# %%
for lb in ['train', 'test']:
    MAE_overall = abs(data_final[lb+'_pred'] - data_final[lb+'_true']).mean()
    MAE_ = abs(data_final[lb+'_pred'] - data_final[lb+'_true']).mean(axis=(1, 2))
    plt.figure(figsize=(15, 3))
    plt.plot(MAE_)
    plt.title('MAE '+lb+': overall MAE = '+str(MAE_overall))
    plt.show()

# %% [markdown]
# Based on the above plots, we can say that there are still certain periodical pattens in both train and test MAE. Training for more epochs may lead to better results.
#
# Next we are going to check some random samples and see if the predicted lines and corresponding true lines are aligned.

# %%
ith_timestep = random.choice(range(data_final[lb+'_pred'].shape[1]))
print('{} among {}'.format(ith_timestep, data_final[lb+'_pred'].shape[1]))

plt.figure(figsize=(15, 5))
train_start_t = 0
test_start_t = data_final['train_pred'].shape[0]

for lb, tm, clrs in zip(['train', 'test'], [train_start_t, test_start_t], [['green', 'red'], ['blue', 'orange']]):
    for i, x_lbl in zip([0, 1], ['x1', 'x2']):
        plt.plot(range(tm, tm+data_final[lb+'_pred'].shape[0]), 
                 data_final[lb+'_pred'][:, ith_timestep, i], 
                 linestyle='--', linewidth=1, color=clrs[0], label='pred '+x_lbl)
        plt.plot(range(tm, tm+data_final[lb+'_pred'].shape[0]), 
                 data_final[lb+'_true'][:, ith_timestep, i], 
                 linestyle='-', linewidth=1, color=clrs[1], label='true '+x_lbl)
    
plt.title('{}th time step in all samples'.format(ith_timestep))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=8)
plt.show()
# Out:
# 0 among 20

# %% [markdown]
# Take a closer look at the prediction on test set:

# %%
lb = 'test'
plt.figure(figsize=(15, 5))
for i, x_lbl, clr in zip([0, 1], ['x1', 'x2'], ['green', 'blue']):
    plt.plot(data_final[lb+'_pred'][:, ith_timestep, i], linestyle='--', color=clr, label='pred '+x_lbl)
    plt.plot(data_final[lb+'_true'][:, ith_timestep, i], linestyle='-', color=clr, label='true '+x_lbl)
plt.title('({}): {}th time step in all samples'.format(lb, ith_timestep))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# ### References
# * Huangwei Wieniawska, Building Seq2Seq LSTM with Luong Attention in Keras for Time Series Forecasting, 2020
# https://levelup.gitconnected.com/building-seq2seq-lstm-with-luong-attention-in-keras-for-time-series-forecasting-1ee00958decb
#
# * 양방향 LSTM과 어텐션 메커니즘(BiLSTM with Attention mechanism), https://wikidocs.net/48920
